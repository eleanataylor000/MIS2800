# %% [markdown]
# <a href="https://colab.research.google.com/github/eleanataylor000/MIS2800/blob/main/Taylor_HW3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Type this code exactly as shown to intall the first library needed for
# !pip install --upgrade pandas ipython-sql prettytable==3.10.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 59.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 50.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: prettytable
#     Found existing installation: prettytable 3.17.0
#     Uninstalling prettytable-3.17.0:
#       Successfully uninstalled prettytable-3.17.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.0 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.0 which is incompatible.
# ...

# %%
# Install the SQL extension. Remember to type exactly as shown here.
# !pip install ipython-sql
print("ipython sql installed")
# Out:
# ...
# ipython sql installed

# %%
# Load the SQL magic extension
# %load_ext sql

# %%
#this code imports sqlite3 and prints a statement stating it has been im
import sqlite3
print("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
# This creates a brand-new, empty database file named 'AdCampaigns2026.d
conn = sqlite3.connect('AdCampaigns2026.db')
print("database created")
# Out:
# database created

# %%
# This line is required so Colab stops acting like Python and acts more
# %sql sqlite:///AdCampaigns2026.db

# %%
#Block
# Instructions: There is a typo in the table. Hint: a word is missing.
# %%sql
CREATE TABLE Marketing_Brands (
brand_id INTEGER PRIMARY KEY,
brand_name TEXT,
brand_type TEXT,
brand_budget INTEGER
) STRICT;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# []

# %%
#Block 2
# Instructions: Find and fix the error.
# %%sql
INSERT INTO Marketing_Brands (brand_id, brand_name, brand_type, brand_budget)
VALUES
(1, 'Doritos', 'Snacks', 7000000),
(2, 'AWS', 'Technology', 15000000),
(3, 'Pepsi', 'Beverages', 2000000),
(4, 'He_Gets_Us', 'Religious', 1000000),
(5, 'Dr_Pepper', 'Beverages', 5000000),
(6, 'IBM', 'Technology', 100000),
(7, 'Google', 'Technology', 8000000);
# Out:
#  * sqlite:///AdCampaigns2026.db
# 7 rows affected.
# []

# %%
#Block 3
# %%sql
-- Instructions: Fix the code to select all the columns from the Marketi
SELECT * FROM Marketing_Brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (2, 'AWS', 'Technology', 15000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (6, 'IBM', 'Technology', 100000),
#  (7, 'Google', 'Technology', 8000000)]

# %%
#Block 4
# %%sql
SELECT brand_name, brand_type FROM Marketing_Brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos', 'Snacks'),
#  ('AWS', 'Technology'),
#  ('Pepsi', 'Beverages'),
#  ('He_Gets_Us', 'Religious'),
#  ('Dr_Pepper', 'Beverages'),
#  ('IBM', 'Technology'),
#  ('Google', 'Technology')]

# %%
#Block 5
# %%sql
SELECT * FROM Marketing_Brands WHERE brand_type = 'Religious';
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(4, 'He_Gets_Us', 'Religious', 1000000)]

# %%
#Block 6
# %%sql
SELECT brand_name FROM Marketing_Brands WHERE brand_budget > 5000000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos',), ('AWS',), ('Google',)]

# %%
#Block 7
# %%sql
SELECT * FROM Marketing_Brands WHERE brand_budget > 7000000
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(2, 'AWS', 'Technology', 15000000), (7, 'Google', 'Technology', 8000000)]

# %%
#Block 8
# %%sql
SELECT * FROM Marketing_Brands WHERE brand_type = 'Snacks' OR brand_type = 'Beverages';
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000)]

# %%
#Block 9
# %%sql
SELECT * FROM Marketing_Brands ORDER BY brand_budget DESC;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(2, 'AWS', 'Technology', 15000000),
#  (7, 'Google', 'Technology', 8000000),
#  (1, 'Doritos', 'Snacks', 7000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (6, 'IBM', 'Technology', 100000)]

# %%
#Block 10
# %%sql
SELECT * FROM Marketing_Brands ORDER BY brand_budget ASC;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(6, 'IBM', 'Technology', 100000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (1, 'Doritos', 'Snacks', 7000000),
#  (7, 'Google', 'Technology', 8000000),
#  (2, 'AWS', 'Technology', 15000000)]

# %% [markdown]
# # Answer the Questions Below Based on the SQL Code You've Run Above
#
# 1. How did you fix the error in Block #1? Answer: Missing “TABLE” after CREATE;
# Used/referenced IC_Feb4
#
# 2. How did you fix the error in Block #2? Answer: Missing “INTO” and table name “Marketing_Brands”;
# Used/referenced IC_Feb4
#
# 3. How did you fix the error in Block #3? Answer: Missing “*” to include full table;
# Used/referenced IC_Feb4
#
# 4. How did you fix the error in Block #4? Answer: Missing “brand_name and brand_type”;
# Used AI for placement in the code because the one I created ran but didn’t display correctly
#
# 5. How did you fix the error in Block #5? Answer: Missing WHERE function and “religious” brand_type;
# Used AI to add in function
#
# 6. How did you fix the error in Block #6? Answer: Missing “> 5000000”;
# Used AI to display brand names with bud
#
# 7. How did you fix the error in Block #7? Answer: Missing “> 7000000”;
# Used AI to run SQLite3
#
# 8. How did you fix the error in Block #8? Answer: Added OR function and two brand types: “Snacks” and “Beverages”;
# Used AI to build code
#
# 9. How did you fix the error in Block #9? Answer: Added ORDER BY and DESC functions;
# Used AI to build code
#
# 10. How did you fix the error in Block #10? Answer: Swtiched out the DESC function for ASC;
# Used/referenced Block 9
